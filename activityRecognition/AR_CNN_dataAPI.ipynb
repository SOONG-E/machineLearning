# %%
import tensorflow as tf
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from tensorflow import keras
from keras.models import Input, Model
from keras.layers import TimeDistributed, LSTM
from keras.layers import ConvLSTM2D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, LeakyReLU, BatchNormalization
from keras.layers import Dense, Flatten, GlobalMaxPooling2D
from keras.layers import MaxPooling3D
from keras.layers import concatenate
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
frames = 15
Width = 256
Height = 256

# %%
def load_video_names(path):
  videos = []
  labels = []
  videos_val = []
  labels_val = []
  amount = []

  for i in os.walk(path): # 디렉토리 내의 파일 개수
    amount.append(len(i[2]))
  amount.pop(0)

  amount = [i * 0.7 for i in amount]

  for category, amount in zip(os.listdir(path),amount):
    i = 0
    for video in os.listdir(path+"/"+category):
      if i <= amount:
          videos.append(path+"/"+category+"/"+video)
          labels.append(category)
      else:
          videos_val.append(path+"/"+category+"/"+video)
          labels_val.append(category)
      i += 1
  return videos, labels, videos_val, labels_val

#normalize pixel(-1, 1)
def preprocess(frame):
  frame = cv2.resize(frame, (Width, Height))
  frame = frame - 127.5
  frame = frame / 127.5
  return frame


def load_video(video_path):
  video_frames = []
  cap = cv2.VideoCapture(video_path)
  while True:
    ret, frame = cap.read()
    if ret == True:
      video_frames.append(preprocess(frame))  #프레임 다 저장
    else:
      break
  cap.release()
  video_frames = select_frame(video_frames)
  if len(video_frames) != frames:
    print('short_video ', video_path, len(video_frames))

  return np.array(video_frames)


def select_frame(video_frames):
  selected_frames = []
  if len(video_frames) > frames:
    fn = len(video_frames)//frames
    f_num=0
    for f in video_frames:
      if len(selected_frames) < frames:
        if f_num % fn == 0:
          selected_frames.append(f)
      f_num += 1
  else:
    selected_frames = video_frames
  return selected_frames


def create_dataset(videos, labels):
  videos = videos.numpy()
  videos = videos.astype(str)
  X = load_video(videos[0])
    
  return X, labels

# %%
def onehot_encode_label(labels):
  labels_counts = np.unique(labels, return_counts = True)
  le = LabelEncoder()

  encoded_labels = le.fit_transform(labels)
  encoded_labels = np.reshape(encoded_labels, (-1, 1))

  encoder = OneHotEncoder()
  encoded_labels = encoder.fit_transform(encoded_labels)

  encoded_labels = encoded_labels.toarray()

  return encoded_labels

# %%
def res_block(model, filters):
  start_block = model
  model = Conv2D(filters = filters, kernel_size = 3, padding = 'same')(model)
  model = BatchNormalization(momentum = 0.9)(model)
  model = LeakyReLU(0.2)(model)
  return concatenate([start_block, model])


def create_model():

  model = tf.keras.models.Sequential()
  input_layer = Input(shape = (frames, Width, Height, 3))

  model = ConvLSTM2D(32, 3, padding = 'same', return_sequences= False)(input_layer)
  model = BatchNormalization(momentum = 0.9)(model)
  model = LeakyReLU(0.2)(model)

  filters = 64

  for _ in range(6):
    model = res_block(model, filters)
    try:
      model = MaxPooling3D((2, 2, 2))(model)
    except:
      model = MaxPooling2D((2, 2))(model)
    if filters < 512 :
      filters *= 2

  classes = len(np.unique(labels))
  model = Flatten()(model)

  model = Dense(classes, activation = 'softmax')(model)

  model = Model(input_layer, model)

  model.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
  #model.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
  return model

# %%
videos, labels, videos_val, labels_val = load_video_names('/content/drive/MyDrive/HAR/AR_CNN_1/hmdb51')

# %%
classifier = create_model()

# %%
classifier.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 15, 256, 256 0
# __________________________________________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)     (None, 256, 256, 32) 40448       input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 32) 128         conv_lst_m2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 64) 18496       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 256, 256, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 256, 256, 96) 0           leaky_re_lu_14[0][0]
#                                                                  leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 128, 128, 96) 0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 110720      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 128, 128 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 224 0           max_pooling2d_12[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 64, 64, 224)  0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  516352      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 64, 64, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 64, 64, 480)  0           max_pooling2d_13[0][0]
#                                                                  leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 32, 32, 480)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 512)  2212352     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 32, 32, 512)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 32, 32, 992)  0           max_pooling2d_14[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 992)  0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 512)  4571648     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 512)  2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 16, 16, 512)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 16, 16, 1504) 0           max_pooling2d_15[0][0]
#                                                                  leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 1504)   0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 512)    6930944     max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 8, 8, 512)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 2016)   0           max_pooling2d_16[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 2016)   0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 32256)        0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 17)           548369      flatten_2[0][0]
# ==================================================================================================
# Total params: 14,957,393
# Trainable params: 14,953,361
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
# %cd /content/drive/MyDrive/HAR/AR_CNN_1
# Out:
# /content/drive/MyDrive/HAR/AR_CNN_1

# %%
model_name = 'AR_1.h5'

# %%
checkpoint_cb=keras.callbacks.ModelCheckpoint(
    model_name,
    monitor='val_accuracy', verbose=1, save_best_only=True, save_freq= 'epoch')

early_stopping_cb=keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
def _fixup_shape(images, labels):
    images.set_shape([None, 15, 256, 256, 3])
    labels.set_shape([None, 12])
    return images, labels

# %%
def reader_dataset(videos, labels, repeat = 1, n_parse_threads = 5, batch_size = 5, shuffle_buffer_size = 100):
  y = onehot_encode_label(labels)
  print(y.shape)
  dataset = tf.data.Dataset.from_tensor_slices((videos, y)).repeat(repeat)
  dataset = dataset.shuffle(shuffle_buffer_size)
  dataset = dataset.map(lambda path, label : tf.py_function(create_dataset, [[path], label], [tf.float64, tf.float64]), num_parallel_calls = n_parse_threads)

  return dataset.batch(batch_size, drop_remainder = True).map(_fixup_shape).prefetch(1)

# %%
train_set = reader_dataset(videos, labels)
valid_set = reader_dataset(videos_val, labels_val)
# Out:
# (1428, 12)
# (601, 12)

# %%
print(train_set)
# Out:
# <PrefetchDataset shapes: ((None, 15, 256, 256, 3), (None, 12)), types: (tf.float64, tf.float64)>

# %%
try:
  classifier.load_weights(model_name)
  print("success")
except:
  pass

# %%
history = classifier.fit(train_set, epochs=30, validation_data = valid_set, callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/30
# 285/285 [==============================] - 2062s 7s/step - loss: 4.6325 - accuracy: 0.5078 - val_loss: 12.7119 - val_accuracy: 0.2167
#
# Epoch 00001: val_accuracy improved from -inf to 0.21667, saving model to AR_1.h5
# Epoch 2/30
# 285/285 [==============================] - 513s 2s/step - loss: 5.4091 - accuracy: 0.4502 - val_loss: 10.0531 - val_accuracy: 0.2733
#
# Epoch 00002: val_accuracy improved from 0.21667 to 0.27333, saving model to AR_1.h5
# Epoch 3/30
# 285/285 [==============================] - 511s 2s/step - loss: 4.6447 - accuracy: 0.4750 - val_loss: 11.8732 - val_accuracy: 0.2483
#
# Epoch 00003: val_accuracy did not improve from 0.27333
# Epoch 4/30
# 285/285 [==============================] - 511s 2s/step - loss: 5.5456 - accuracy: 0.4536 - val_loss: 16.3805 - val_accuracy: 0.2167
#
# Epoch 00004: val_accuracy did not improve from 0.27333
# Epoch 5/30
# 285/285 [==============================] - 513s 2s/step - loss: 5.7192 - accuracy: 0.4370 - val_loss: 14.8250 - val_accuracy: 0.2600
#
# Epoch 00005: val_accuracy did not improve from 0.27333
# Epoch 6/30
# 285/285 [==============================] - 515s 2s/step - loss: 5.6261 - accuracy: 0.4431 - val_loss: 8.3008 - val_accuracy: 0.2433
#
# Epoch 00006: val_accuracy did not improve from 0.27333
# Epoch 7/30
# 285/285 [==============================] - 517s 2s/step - loss: 3.9917 - accuracy: 0.4644 - val_loss: 10.9663 - val_accuracy: 0.2350
#
# Epoch 00007: val_accuracy did not improve from 0.27333
# Epoch 8/30
# 285/285 [==============================] - 517s 2s/step - loss: 3.9821 - accuracy: 0.4733 - val_loss: 13.2585 - val_accuracy: 0.2317
#
# Epoch 00008: val_accuracy did not improve from 0.27333
# Epoch 9/30
# 285/285 [==============================] - 524s 2s/step - loss: 4.5892 - accuracy: 0.4591 - val_loss: 13.4053 - val_accuracy: 0.2617
#
# Epoch 00009: val_accuracy did not improve from 0.27333
# Epoch 10/30
# 285/285 [==============================] - 508s 2s/step - loss: 4.2450 - accuracy: 0.4306 - val_loss: 10.2370 - val_accuracy: 0.2683
#
# Epoch 00010: val_accuracy did not improve from 0.27333
# Epoch 11/30
# 285/285 [==============================] - 523s 2s/step - loss: 4.0934 - accuracy: 0.4561 - val_loss: 10.5363 - val_accuracy: 0.2633
#
# Epoch 00011: val_accuracy did not improve from 0.27333
# Epoch 12/30
# 285/285 [==============================] - 518s 2s/step - loss: 3.6068 - accuracy: 0.4980 - val_loss: 10.7575 - val_accuracy: 0.2733
#
# Epoch 00012: val_accuracy did not improve from 0.27333
# Epoch 13/30
# 285/285 [==============================] - 498s 2s/step - loss: 3.4949 - accuracy: 0.4789 - val_loss: 8.1994 - val_accuracy: 0.2500
#
# Epoch 00013: val_accuracy did not improve from 0.27333
# Epoch 14/30
# 285/285 [==============================] - 526s 2s/step - loss: 3.8221 - accuracy: 0.4303 - val_loss: 8.2618 - val_accuracy: 0.2267
#
# Epoch 00014: val_accuracy did not improve from 0.27333
# Epoch 15/30
# 285/285 [==============================] - 526s 2s/step - loss: 2.9985 - accuracy: 0.4686 - val_loss: 9.1104 - val_accuracy: 0.0867
#
# Epoch 00015: val_accuracy did not improve from 0.27333
# Epoch 16/30
# 285/285 [==============================] - 514s 2s/step - loss: 3.1199 - accuracy: 0.4609 - val_loss: 14.1378 - val_accuracy: 0.2283
#
# Epoch 00016: val_accuracy did not improve from 0.27333
# Epoch 17/30
# 285/285 [==============================] - 517s 2s/step - loss: 3.6454 - accuracy: 0.4525 - val_loss: 5.9986 - val_accuracy: 0.1100
#
# Epoch 00017: val_accuracy did not improve from 0.27333
# Epoch 18/30
# 285/285 [==============================] - 514s 2s/step - loss: 3.2102 - accuracy: 0.4658 - val_loss: 7.2282 - val_accuracy: 0.0983
#
# Epoch 00018: val_accuracy did not improve from 0.27333
# Epoch 19/30
# 285/285 [==============================] - 506s 2s/step - loss: 2.8359 - accuracy: 0.4915 - val_loss: 10.6418 - val_accuracy: 0.0717
#
# Epoch 00019: val_accuracy did not improve from 0.27333
# Epoch 20/30
# 285/285 [==============================] - 500s 2s/step - loss: 2.9939 - accuracy: 0.4580 - val_loss: 9.0450 - val_accuracy: 0.0900
#
# Epoch 00020: val_accuracy did not improve from 0.27333
# Epoch 21/30
# 285/285 [==============================] - 512s 2s/step - loss: 3.1045 - accuracy: 0.4290 - val_loss: 9.7740 - val_accuracy: 0.2433
#
# Epoch 00021: val_accuracy did not improve from 0.27333
# Epoch 22/30
# 285/285 [==============================] - 508s 2s/step - loss: 2.8296 - accuracy: 0.4441 - val_loss: 7.6519 - val_accuracy: 0.1550
#
# Epoch 00022: val_accuracy did not improve from 0.27333
# Epoch 23/30
# 285/285 [==============================] - 515s 2s/step - loss: 2.7408 - accuracy: 0.4766 - val_loss: 7.8831 - val_accuracy: 0.2083
#
# Epoch 00023: val_accuracy did not improve from 0.27333
# Epoch 24/30
# 285/285 [==============================] - 517s 2s/step - loss: 2.2902 - accuracy: 0.4584 - val_loss: 7.6959 - val_accuracy: 0.0967
#
# Epoch 00024: val_accuracy did not improve from 0.27333
# Epoch 25/30
# 285/285 [==============================] - 518s 2s/step - loss: 2.4607 - accuracy: 0.4485 - val_loss: 8.3291 - val_accuracy: 0.1633
#
# Epoch 00025: val_accuracy did not improve from 0.27333
# Epoch 26/30
# 285/285 [==============================] - 515s 2s/step - loss: 2.5711 - accuracy: 0.4733 - val_loss: 10.0593 - val_accuracy: 0.2267
#
# Epoch 00026: val_accuracy did not improve from 0.27333
# Epoch 27/30
# 285/285 [==============================] - 498s 2s/step - loss: 2.3776 - accuracy: 0.4663 - val_loss: 7.2880 - val_accuracy: 0.2050
#
# Epoch 00027: val_accuracy did not improve from 0.27333

# %%
classifier.save_weights(model_name)

# %% [markdown]
# test

# %%
dataset_X = tf.data.Dataset.from_tensor_slices((videos, y)).repeat(2)
dataset_X = dataset_X.map(lambda path, label : tf.py_function(create_dataset, [[path], label], [tf.float64, tf.float64]))

y = onehot_encode_label(labels)
dataset_y = tf.data.Dataset.from_tensor_slices(y).repeat(2)

for i in dataset_X:
  print(i)
# Out:
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.28627451,  0.01960784, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         ...,
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.41960784, -0.06666667, -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]],
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.41960784, -0.06666667, -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.41176471, -0.0745098 , -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]]],
#
#
#        [[[-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         ...,
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.38823529, -0.08235294, -0.12941176],
#          [-0.38823529, -0.08235294, -0.12941176],
#          [-0.38823529, -0.08235294, -0.12941176]],
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]]],
#
#
#        [[[-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05098039, -0.05098039],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         [[-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05882353, -0.04313725],
#          [-0.25490196,  0.06666667, -0.03529412],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         [[-0.25490196,  0.05882353, -0.03529412],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.24705882,  0.06666667, -0.02745098],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         ...,
#
#         [[-0.29411765, -0.02745098, -0.06666667],
#          [-0.29411765, -0.01960784, -0.05882353],
#          [-0.29411765, -0.00392157, -0.04313725],
#          ...,
#          [-0.6       , -0.12941176, -0.2       ],
#          [-0.56078431, -0.09019608, -0.16078431],
#          [-0.5372549 , -0.06666667, -0.1372549 ]],
#
#         [[-0.30980392, -0.02745098, -0.06666667],
#          [-0.30980392, -0.01960784, -0.05882353],
#          [-0.29411765, -0.01176471, -0.05098039],
#          ...,
#          [-0.63921569, -0.12156863, -0.20784314],
#          [-0.56078431, -0.08235294, -0.16078431],
#          [-0.52156863, -0.06666667, -0.1372549 ]],
#
#         [[-0.31764706, -0.03529412, -0.0745098 ],
#          [-0.31764706, -0.03529412, -0.0745098 ],
#          [-0.30196078, -0.01960784, -0.05882353],
#          ...,
#          [-0.63137255, -0.12156863, -0.2       ],
#          [-0.55294118, -0.08235294, -0.15294118],
#          [-0.50588235, -0.05098039, -0.12156863]]],
#
#
#        ...,
#
#
#        [[[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         [[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         [[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         ...,
#
#         [[-0.36470588, -0.04313725, -0.10588235],
#          [-0.35686275, -0.04313725, -0.10588235],
#          [-0.34117647, -0.03529412, -0.09803922],
#          ...,
#          [-0.57647059, -0.16078431, -0.23921569],
#          [-0.60784314, -0.17647059, -0.2627451 ],
#          [-0.62352941, -0.18431373, -0.27058824]],
#
#         [[-0.35686275, -0.05098039, -0.11372549],
#          [-0.35686275, -0.05098039, -0.11372549],
#          [-0.34117647, -0.04313725, -0.10588235],
#          ...,
#          [-0.56078431, -0.14509804, -0.20784314],
#          [-0.59215686, -0.16078431, -0.23137255],
#          [-0.60784314, -0.16862745, -0.23921569]],
#
#         [[-0.35686275, -0.05098039, -0.11372549],
#          [-0.34901961, -0.04313725, -0.10588235],
#          [-0.34901961, -0.04313725, -0.10588235],
#          ...,
#          [-0.56862745, -0.15294118, -0.21568627],
#          [-0.60784314, -0.17647059, -0.23921569],
#          [-0.62352941, -0.18431373, -0.25490196]]],
#
#
#        [[[-0.60784314, -0.28627451, -0.24705882],
#          [-0.60784314, -0.27843137, -0.24705882],
#          [-0.6       , -0.27058824, -0.24705882],
#          ...,
#          [-0.49803922, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.48235294, -0.12156863, -0.17647059]],
#
#         [[-0.6       , -0.27843137, -0.23921569],
#          [-0.6       , -0.27058824, -0.23921569],
#          [-0.59215686, -0.2627451 , -0.23921569],
#          ...,
#          [-0.49803922, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.48235294, -0.12156863, -0.17647059]],
#
#         [[-0.59215686, -0.27058824, -0.23137255],
#          [-0.58431373, -0.2627451 , -0.23137255],
#          [-0.57647059, -0.24705882, -0.22352941],
#          ...,
#          [-0.48235294, -0.10588235, -0.16078431],
#          [-0.4745098 , -0.10588235, -0.16078431],
#          [-0.46666667, -0.10588235, -0.16078431]],
#
#         ...,
#
#         [[-0.29411765, -0.01176471, -0.06666667],
#          [-0.28627451, -0.00392157, -0.05882353],
#          [-0.28627451,  0.00392157, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.50588235, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]],
#
#         [[-0.31764706,  0.00392157, -0.05882353],
#          [-0.30196078,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.50588235, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]],
#
#         [[-0.31764706,  0.00392157, -0.05882353],
#          [-0.30980392,  0.00392157, -0.05882353],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.51372549, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]]],
#
#
#        [[[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         ...,
#
#         [[-0.23921569,  0.04313725, -0.01176471],
#          [-0.25490196,  0.01960784, -0.02745098],
#          [-0.23921569,  0.04313725, -0.01176471],
#          ...,
#          [-0.96862745, -0.56862745, -0.63137255],
#          [-0.99215686, -0.74117647, -0.78823529],
#          [-1.        , -0.81960784, -0.84313725]],
#
#         [[-0.24705882,  0.04313725,  0.00392157],
#          [-0.25490196,  0.01960784, -0.01960784],
#          [-0.23921569,  0.04313725,  0.00392157],
#          ...,
#          [-0.99215686, -0.59215686, -0.64705882],
#          [-1.        , -0.74901961, -0.79607843],
#          [-1.        , -0.81960784, -0.85098039]],
#
#         [[-0.25490196,  0.02745098, -0.01176471],
#          [-0.2627451 ,  0.01960784, -0.01960784],
#          [-0.23921569,  0.04313725,  0.00392157],
#          ...,
#          [-0.97647059, -0.57647059, -0.63137255],
#          [-1.        , -0.77254902, -0.81176471],
#          [-1.        , -0.85882353, -0.89019608]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314]],
#
#         [[-0.28627451,  0.01176471, -0.01960784],
#          [-0.28627451,  0.01176471, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          ...,
#          [-0.45882353, -0.15294118, -0.2       ],
#          [-0.45882353, -0.15294118, -0.2       ],
#          [-0.45882353, -0.15294118, -0.2       ]],
#
#         [[-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          ...,
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314]],
#
#         ...,
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.43529412, -0.05882353, -0.11372549],
#          ...,
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.55294118, -0.10588235, -0.17647059],
#          [-0.56078431, -0.10588235, -0.17647059]],
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          ...,
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.54509804, -0.10588235, -0.17647059]],
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          ...,
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.54509804, -0.10588235, -0.17647059]]],
#
#
#        [[[-0.30196078,  0.01960784, -0.08235294],
#          [-0.30196078,  0.01960784, -0.08235294],
#          [-0.30196078,  0.01960784, -0.08235294],
#          ...,
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ]],
#
#         [[-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          ...,
#          [-0.52941176, -0.15294118, -0.20784314],
#          [-0.52941176, -0.15294118, -0.20784314],
#          [-0.52941176, -0.15294118, -0.20784314]],
#
#         [[-0.30196078,  0.00392157, -0.05882353],
#          [-0.30196078,  0.00392157, -0.05882353],
#          [-0.30196078,  0.00392157, -0.05882353],
#          ...,
#          [-0.51372549, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         ...,
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.43529412, -0.05882353, -0.11372549],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.56862745, -0.12941176, -0.19215686],
#          [-0.57647059, -0.12941176, -0.19215686],
#          [-0.56862745, -0.11372549, -0.18431373]],
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.43529412, -0.05882353, -0.11372549],
#          ...,
#          [-0.56862745, -0.12941176, -0.19215686],
#          [-0.56862745, -0.12941176, -0.19215686],
#          [-0.55294118, -0.11372549, -0.18431373]],
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.43529412, -0.05882353, -0.11372549],
#          ...,
#          [-0.56862745, -0.12941176, -0.2       ],
#          [-0.56862745, -0.12941176, -0.2       ],
#          [-0.55294118, -0.11372549, -0.18431373]]],
#
#
#        [[[-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          ...,
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ]],
#
#         [[-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          [-0.29411765,  0.02745098, -0.0745098 ],
#          ...,
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ],
#          [-0.52156863, -0.14509804, -0.2       ]],
#
#         [[-0.29411765,  0.00392157, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.04313725],
#          ...,
#          [-0.51372549, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         ...,
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.41960784, -0.04313725, -0.10588235],
#          ...,
#          [-0.56862745, -0.08235294, -0.16078431],
#          [-0.57647059, -0.08235294, -0.16078431],
#          [-0.58431373, -0.08235294, -0.16078431]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.57647059, -0.10588235, -0.17647059],
#          [-0.58431373, -0.11372549, -0.18431373],
#          [-0.58431373, -0.11372549, -0.18431373]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.59215686, -0.12941176, -0.2       ],
#          [-0.6       , -0.12941176, -0.2       ],
#          [-0.6       , -0.12941176, -0.2       ]]],
#
#
#        ...,
#
#
#        [[[-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          ...,
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ]],
#
#         [[-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          ...,
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ]],
#
#         [[-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          ...,
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ],
#          [-0.4745098 , -0.15294118, -0.2       ]],
#
#         ...,
#
#         [[-0.33333333,  0.01176471, -0.04313725],
#          [-0.3254902 ,  0.01960784, -0.03529412],
#          [-0.31764706,  0.01960784, -0.02745098],
#          ...,
#          [-0.52156863, -0.10588235, -0.09019608],
#          [-0.60784314, -0.19215686, -0.18431373],
#          [-0.6627451 , -0.25490196, -0.24705882]],
#
#         [[-0.33333333,  0.01176471, -0.04313725],
#          [-0.3254902 ,  0.01960784, -0.03529412],
#          [-0.31764706,  0.01960784, -0.02745098],
#          ...,
#          [-0.48235294, -0.0745098 , -0.06666667],
#          [-0.58431373, -0.16078431, -0.16078431],
#          [-0.65490196, -0.23137255, -0.22352941]],
#
#         [[-0.33333333,  0.01176471, -0.04313725],
#          [-0.33333333,  0.01176471, -0.04313725],
#          [-0.3254902 ,  0.02745098, -0.02745098],
#          ...,
#          [-0.48235294, -0.0745098 , -0.06666667],
#          [-0.57647059, -0.16078431, -0.15294118],
#          [-0.65490196, -0.22352941, -0.21568627]]],
#
#
#        [[[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.44313725, -0.1372549 , -0.18431373],
#          [-0.44313725, -0.1372549 , -0.18431373],
#          [-0.44313725, -0.1372549 , -0.18431373]],
#
#         [[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686]],
#
#         [[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686]],
#
#         ...,
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.05882353,  0.01960784],
#          ...,
#          [-0.49803922, -0.15294118, -0.12941176],
#          [-0.5372549 , -0.21568627, -0.20784314],
#          [-0.56078431, -0.25490196, -0.25490196]],
#
#         [[-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          [-0.23921569,  0.06666667,  0.01176471],
#          ...,
#          [-0.46666667, -0.11372549, -0.11372549],
#          [-0.51372549, -0.17647059, -0.18431373],
#          [-0.54509804, -0.21568627, -0.23137255]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.41176471, -0.05882353, -0.05882353],
#          [-0.46666667, -0.12941176, -0.1372549 ],
#          [-0.52156863, -0.19215686, -0.20784314]]],
#
#
#        [[[-0.25490196,  0.06666667, -0.03529412],
#          [-0.25490196,  0.06666667, -0.03529412],
#          [-0.25490196,  0.06666667, -0.03529412],
#          ...,
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608]],
#
#         [[-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          ...,
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608]],
#
#         [[-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         ...,
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.49019608, -0.16078431, -0.17647059],
#          [-0.55294118, -0.17647059, -0.22352941],
#          [-0.58431373, -0.17647059, -0.24705882]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.48235294, -0.14509804, -0.16078431],
#          [-0.5372549 , -0.14509804, -0.2       ],
#          [-0.56078431, -0.14509804, -0.22352941]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.43529412, -0.09019608, -0.10588235],
#          [-0.49803922, -0.10588235, -0.16078431],
#          [-0.52941176, -0.11372549, -0.19215686]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.06666667,  0.03529412,  0.16078431],
#          [-0.06666667,  0.03529412,  0.16078431],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         [[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.0745098 ,  0.02745098,  0.15294118],
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         [[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         ...,
#
#         [[-0.17647059, -0.0745098 ,  0.14509804],
#          [-0.16862745, -0.06666667,  0.15294118],
#          [-0.16862745, -0.0745098 ,  0.1372549 ],
#          ...,
#          [-0.59215686, -0.52156863, -0.51372549],
#          [-0.58431373, -0.52941176, -0.49019608],
#          [-0.60784314, -0.55294118, -0.50588235]],
#
#         [[-0.33333333, -0.23921569,  0.00392157],
#          [-0.33333333, -0.23921569,  0.00392157],
#          [-0.31764706, -0.23921569, -0.01960784],
#          ...,
#          [-0.63921569, -0.56862745, -0.56078431],
#          [-0.64705882, -0.6       , -0.56078431],
#          [-0.65490196, -0.61568627, -0.56862745]],
#
#         [[-0.90588235, -0.81176471, -0.56862745],
#          [-0.92156863, -0.82745098, -0.59215686],
#          [-0.91372549, -0.82745098, -0.60784314],
#          ...,
#          [-0.97647059, -0.92156863, -0.91372549],
#          [-0.98431373, -0.94509804, -0.90588235],
#          [-0.91372549, -0.8745098 , -0.82745098]]],
#
#
#        [[[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.80392157],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.00392157,  0.06666667],
#          [-0.05882353, -0.01176471,  0.05882353],
#          [-0.05882353, -0.01176471,  0.05882353]],
#
#         [[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.80392157],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.00392157,  0.0745098 ],
#          [-0.05882353, -0.01176471,  0.05882353],
#          [-0.05882353, -0.01176471,  0.05882353]],
#
#         [[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.81176471],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.01176471,  0.05882353],
#          [-0.06666667, -0.01960784,  0.05098039],
#          [-0.06666667, -0.01960784,  0.05098039]],
#
#         ...,
#
#         [[-0.16078431, -0.0745098 ,  0.14509804],
#          [-0.15294118, -0.06666667,  0.14509804],
#          [-0.16862745, -0.0745098 ,  0.1372549 ],
#          ...,
#          [-0.59215686, -0.52156863, -0.51372549],
#          [-0.58431373, -0.52941176, -0.49019608],
#          [-0.60784314, -0.55294118, -0.50588235]],
#
#         [[-0.30980392, -0.22352941, -0.01176471],
#          [-0.31764706, -0.23137255, -0.01176471],
#          [-0.31764706, -0.23137255, -0.01176471],
#          ...,
#          [-0.63921569, -0.56862745, -0.56078431],
#          [-0.64705882, -0.6       , -0.56078431],
#          [-0.65490196, -0.61568627, -0.56862745]],
#
#         [[-0.86666667, -0.78039216, -0.56078431],
#          [-0.89019608, -0.80392157, -0.58431373],
#          [-0.89803922, -0.81176471, -0.59215686],
#          ...,
#          [-0.97647059, -0.92156863, -0.91372549],
#          [-0.98431373, -0.94509804, -0.90588235],
#          [-0.91372549, -0.8745098 , -0.82745098]]],
#
#
#        [[[ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74901961,  0.80392157],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         [[ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74901961,  0.80392157],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         [[ 0.85098039,  0.73333333,  0.82745098],
#          [ 0.85098039,  0.73333333,  0.81960784],
#          [ 0.85098039,  0.74117647,  0.81176471],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         ...,
#
#         [[-0.10588235, -0.06666667,  0.15294118],
#          [-0.11372549, -0.08235294,  0.14509804],
#          [-0.1372549 , -0.09803922,  0.12156863],
#          ...,
#          [-0.6       , -0.5372549 , -0.50588235],
#          [-0.59215686, -0.52941176, -0.49803922],
#          [-0.62352941, -0.56862745, -0.5372549 ]],
#
#         [[-0.27058824, -0.22352941, -0.03529412],
#          [-0.28627451, -0.23921569, -0.05098039],
#          [-0.30196078, -0.2627451 , -0.05098039],
#          ...,
#          [-0.63137255, -0.56862745, -0.5372549 ],
#          [-0.63921569, -0.59215686, -0.56078431],
#          [-0.68627451, -0.63921569, -0.60784314]],
#
#         [[-0.81960784, -0.77254902, -0.58431373],
#          [-0.84313725, -0.80392157, -0.60784314],
#          [-0.85882353, -0.82745098, -0.60784314],
#          ...,
#          [-0.98431373, -0.92156863, -0.89019608],
#          [-0.97647059, -0.92941176, -0.89803922],
#          [-0.96078431, -0.91372549, -0.88235294]]],
#
#
#        ...,
#
#
#        [[[ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         [[ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         [[ 0.94509804,  0.85098039,  0.86666667],
#          [ 0.94509804,  0.85098039,  0.86666667],
#          [ 0.94509804,  0.85098039,  0.86666667],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         ...,
#
#         [[-0.09803922,  0.01960784,  0.10588235],
#          [-0.09803922,  0.01176471,  0.09019608],
#          [-0.10588235, -0.00392157,  0.05098039],
#          ...,
#          [-0.57647059, -0.49803922, -0.52156863],
#          [-0.59215686, -0.50588235, -0.55294118],
#          [-0.60784314, -0.52156863, -0.56078431]],
#
#         [[-0.27843137, -0.16078431, -0.09019608],
#          [-0.27058824, -0.16078431, -0.09019608],
#          [-0.2627451 , -0.16862745, -0.12941176],
#          ...,
#          [-0.60784314, -0.52156863, -0.56862745],
#          [-0.68627451, -0.60784314, -0.63921569],
#          [-0.69411765, -0.61568627, -0.63921569]],
#
#         [[-0.82745098, -0.70980392, -0.63921569],
#          [-0.82745098, -0.71764706, -0.65490196],
#          [-0.81176471, -0.71764706, -0.67843137],
#          ...,
#          [-0.96078431, -0.8745098 , -0.92156863],
#          [-0.97647059, -0.89803922, -0.92156863],
#          [-0.94509804, -0.85882353, -0.89019608]]],
#
#
#        [[[ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          ...,
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059]],
#
#         [[ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.92156863,  0.89803922,  0.90588235],
#          ...,
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059]],
#
#         [[ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.91372549,  0.90588235,  0.90588235],
#          ...,
#          [-0.01960784,  0.0745098 ,  0.16862745],
#          [-0.01176471,  0.0745098 ,  0.16862745],
#          [-0.01176471,  0.0745098 ,  0.16862745]],
#
#         ...,
#
#         [[-0.11372549, -0.01176471,  0.20784314],
#          [-0.09803922, -0.00392157,  0.2       ],
#          [-0.06666667, -0.01176471,  0.12156863],
#          ...,
#          [-0.56078431, -0.48235294, -0.50588235],
#          [-0.56862745, -0.49019608, -0.52941176],
#          [-0.58431373, -0.49803922, -0.54509804]],
#
#         [[-0.28627451, -0.17647059,  0.02745098],
#          [-0.2627451 , -0.16862745,  0.02745098],
#          [-0.22352941, -0.17647059, -0.05098039],
#          ...,
#          [-0.59215686, -0.50588235, -0.55294118],
#          [-0.67058824, -0.59215686, -0.61568627],
#          [-0.67843137, -0.6       , -0.62352941]],
#
#         [[-0.82745098, -0.71764706, -0.51372549],
#          [-0.81176471, -0.71764706, -0.52941176],
#          [-0.76470588, -0.71764706, -0.59215686],
#          ...,
#          [-0.92941176, -0.84313725, -0.89019608],
#          [-0.94509804, -0.86666667, -0.89803922],
#          [-0.91372549, -0.83529412, -0.85882353]]],
#
#
#        [[[ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          ...,
#          [-0.01960784,  0.05882353,  0.19215686],
#          [-0.01176471,  0.05098039,  0.20784314],
#          [-0.00392157,  0.05098039,  0.20784314]],
#
#         [[ 0.91372549,  0.91372549,  0.91372549],
#          [ 0.91372549,  0.91372549,  0.91372549],
#          [ 0.91372549,  0.91372549,  0.91372549],
#          ...,
#          [-0.01960784,  0.05882353,  0.19215686],
#          [-0.00392157,  0.05098039,  0.2       ],
#          [-0.00392157,  0.05098039,  0.20784314]],
#
#         [[ 0.90588235,  0.92941176,  0.92941176],
#          [ 0.90588235,  0.92941176,  0.92941176],
#          [ 0.90588235,  0.92941176,  0.92941176],
#          ...,
#          [-0.01960784,  0.06666667,  0.18431373],
#          [-0.01960784,  0.06666667,  0.18431373],
#          [-0.01960784,  0.06666667,  0.18431373]],
#
#         ...,
#
#         [[-0.01176471,  0.04313725,  0.30196078],
#          [-0.01960784,  0.03529412,  0.27843137],
#          [-0.05098039,  0.01960784,  0.2       ],
#          ...,
#          [-0.4745098 , -0.43529412, -0.45098039],
#          [-0.52156863, -0.45098039, -0.46666667],
#          [-0.55294118, -0.4745098 , -0.49019608]],
#
#         [[-0.20784314, -0.12941176,  0.12941176],
#          [-0.20784314, -0.12941176,  0.11372549],
#          [-0.22352941, -0.1372549 ,  0.02745098],
#          ...,
#          [-0.5372549 , -0.49803922, -0.51372549],
#          [-0.63137255, -0.56862745, -0.56078431],
#          [-0.63921569, -0.56862745, -0.56078431]],
#
#         [[-0.83529412, -0.76470588, -0.50588235],
#          [-0.80392157, -0.73333333, -0.49019608],
#          [-0.80392157, -0.71764706, -0.55294118],
#          ...,
#          [-0.89019608, -0.85098039, -0.86666667],
#          [-0.92156863, -0.85882353, -0.85098039],
#          [-0.86666667, -0.79607843, -0.78823529]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.28627451,  0.01960784, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         ...,
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.41960784, -0.06666667, -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]],
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.41960784, -0.06666667, -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.41176471, -0.0745098 , -0.12941176],
#          [-0.41176471, -0.08235294, -0.12941176],
#          [-0.41176471, -0.09019608, -0.1372549 ]]],
#
#
#        [[[-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          [-0.29411765,  0.01960784, -0.06666667],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.29411765,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         ...,
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.38823529, -0.08235294, -0.12941176],
#          [-0.38823529, -0.08235294, -0.12941176],
#          [-0.38823529, -0.08235294, -0.12941176]],
#
#         [[-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          [-0.41960784, -0.04313725, -0.09803922],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]],
#
#         [[-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          [-0.42745098, -0.05098039, -0.10588235],
#          ...,
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ],
#          [-0.39607843, -0.09019608, -0.1372549 ]]],
#
#
#        [[[-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05098039, -0.05098039],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         [[-0.27058824,  0.05098039, -0.05098039],
#          [-0.27058824,  0.05882353, -0.04313725],
#          [-0.25490196,  0.06666667, -0.03529412],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         [[-0.25490196,  0.05882353, -0.03529412],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.24705882,  0.06666667, -0.02745098],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         ...,
#
#         [[-0.29411765, -0.02745098, -0.06666667],
#          [-0.29411765, -0.01960784, -0.05882353],
#          [-0.29411765, -0.00392157, -0.04313725],
#          ...,
#          [-0.6       , -0.12941176, -0.2       ],
#          [-0.56078431, -0.09019608, -0.16078431],
#          [-0.5372549 , -0.06666667, -0.1372549 ]],
#
#         [[-0.30980392, -0.02745098, -0.06666667],
#          [-0.30980392, -0.01960784, -0.05882353],
#          [-0.29411765, -0.01176471, -0.05098039],
#          ...,
#          [-0.63921569, -0.12156863, -0.20784314],
#          [-0.56078431, -0.08235294, -0.16078431],
#          [-0.52156863, -0.06666667, -0.1372549 ]],
#
#         [[-0.31764706, -0.03529412, -0.0745098 ],
#          [-0.31764706, -0.03529412, -0.0745098 ],
#          [-0.30196078, -0.01960784, -0.05882353],
#          ...,
#          [-0.63137255, -0.12156863, -0.2       ],
#          [-0.55294118, -0.08235294, -0.15294118],
#          [-0.50588235, -0.05098039, -0.12156863]]],
#
#
#        ...,
#
#
#        [[[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         [[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         [[-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          [-0.34117647, -0.03529412, -0.08235294],
#          ...,
#          [-0.49803922, -0.1372549 , -0.19215686],
#          [-0.50588235, -0.1372549 , -0.19215686],
#          [-0.51372549, -0.1372549 , -0.19215686]],
#
#         ...,
#
#         [[-0.36470588, -0.04313725, -0.10588235],
#          [-0.35686275, -0.04313725, -0.10588235],
#          [-0.34117647, -0.03529412, -0.09803922],
#          ...,
#          [-0.57647059, -0.16078431, -0.23921569],
#          [-0.60784314, -0.17647059, -0.2627451 ],
#          [-0.62352941, -0.18431373, -0.27058824]],
#
#         [[-0.35686275, -0.05098039, -0.11372549],
#          [-0.35686275, -0.05098039, -0.11372549],
#          [-0.34117647, -0.04313725, -0.10588235],
#          ...,
#          [-0.56078431, -0.14509804, -0.20784314],
#          [-0.59215686, -0.16078431, -0.23137255],
#          [-0.60784314, -0.16862745, -0.23921569]],
#
#         [[-0.35686275, -0.05098039, -0.11372549],
#          [-0.34901961, -0.04313725, -0.10588235],
#          [-0.34901961, -0.04313725, -0.10588235],
#          ...,
#          [-0.56862745, -0.15294118, -0.21568627],
#          [-0.60784314, -0.17647059, -0.23921569],
#          [-0.62352941, -0.18431373, -0.25490196]]],
#
#
#        [[[-0.60784314, -0.28627451, -0.24705882],
#          [-0.60784314, -0.27843137, -0.24705882],
#          [-0.6       , -0.27058824, -0.24705882],
#          ...,
#          [-0.49803922, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.48235294, -0.12156863, -0.17647059]],
#
#         [[-0.6       , -0.27843137, -0.23921569],
#          [-0.6       , -0.27058824, -0.23921569],
#          [-0.59215686, -0.2627451 , -0.23921569],
#          ...,
#          [-0.49803922, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.48235294, -0.12156863, -0.17647059]],
#
#         [[-0.59215686, -0.27058824, -0.23137255],
#          [-0.58431373, -0.2627451 , -0.23137255],
#          [-0.57647059, -0.24705882, -0.22352941],
#          ...,
#          [-0.48235294, -0.10588235, -0.16078431],
#          [-0.4745098 , -0.10588235, -0.16078431],
#          [-0.46666667, -0.10588235, -0.16078431]],
#
#         ...,
#
#         [[-0.29411765, -0.01176471, -0.06666667],
#          [-0.28627451, -0.00392157, -0.05882353],
#          [-0.28627451,  0.00392157, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.50588235, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]],
#
#         [[-0.31764706,  0.00392157, -0.05882353],
#          [-0.30196078,  0.01176471, -0.05098039],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.50588235, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]],
#
#         [[-0.31764706,  0.00392157, -0.05882353],
#          [-0.30980392,  0.00392157, -0.05882353],
#          [-0.29411765,  0.01176471, -0.05098039],
#          ...,
#          [-0.51372549, -0.05882353, -0.12941176],
#          [-0.51372549, -0.05098039, -0.12941176],
#          [-0.49019608, -0.03529412, -0.10588235]]],
#
#
#        [[[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          ...,
#          [-0.46666667, -0.12156863, -0.17647059],
#          [-0.49019608, -0.12156863, -0.17647059],
#          [-0.49803922, -0.12156863, -0.17647059]],
#
#         ...,
#
#         [[-0.23921569,  0.04313725, -0.01176471],
#          [-0.25490196,  0.01960784, -0.02745098],
#          [-0.23921569,  0.04313725, -0.01176471],
#          ...,
#          [-0.96862745, -0.56862745, -0.63137255],
#          [-0.99215686, -0.74117647, -0.78823529],
#          [-1.        , -0.81960784, -0.84313725]],
#
#         [[-0.24705882,  0.04313725,  0.00392157],
#          [-0.25490196,  0.01960784, -0.01960784],
#          [-0.23921569,  0.04313725,  0.00392157],
#          ...,
#          [-0.99215686, -0.59215686, -0.64705882],
#          [-1.        , -0.74901961, -0.79607843],
#          [-1.        , -0.81960784, -0.85098039]],
#
#         [[-0.25490196,  0.02745098, -0.01176471],
#          [-0.2627451 ,  0.01960784, -0.01960784],
#          [-0.23921569,  0.04313725,  0.00392157],
#          ...,
#          [-0.97647059, -0.57647059, -0.63137255],
#          [-1.        , -0.77254902, -0.81176471],
#          [-1.        , -0.85882353, -0.89019608]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.01176471, -0.03529412],
#          ...,
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314]],
#
#         [[-0.28627451,  0.01176471, -0.01960784],
#          [-0.28627451,  0.01176471, -0.02745098],
#          [-0.28627451,  0.01960784, -0.02745098],
#          ...,
#          [-0.45882353, -0.15294118, -0.2       ],
#          [-0.45882353, -0.15294118, -0.2       ],
#          [-0.45882353, -0.15294118, -0.2       ]],
#
#         [[-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          [-0.29411765,  0.00392157, -0.02745098],
#          ...,
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314],
#          [-0.46666667, -0.16078431, -0.20784314]],
#
#         ...,
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.43529412, -0.05882353, -0.11372549],
#          ...,
#          [-0.54509804, -0.10588235, -0.17647059],
#          [-0.55294118, -0.10588235, -0.17647059],
#          [-0.56078431, -0.10588235, -0.17647059]],
#
#         [[-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          [-0.44313725, -0.06666667, -0.12156863],
#          ...,
#          [-0.54509804, -0.10588235, -0.17647059],
# ...
#          ...,
#          [-0.48235294, -0.0745098 , -0.06666667],
#          [-0.58431373, -0.16078431, -0.16078431],
#          [-0.65490196, -0.23137255, -0.22352941]],
#
#         [[-0.33333333,  0.01176471, -0.04313725],
#          [-0.33333333,  0.01176471, -0.04313725],
#          [-0.3254902 ,  0.02745098, -0.02745098],
#          ...,
#          [-0.48235294, -0.0745098 , -0.06666667],
#          [-0.57647059, -0.16078431, -0.15294118],
#          [-0.65490196, -0.22352941, -0.21568627]]],
#
#
#        [[[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.44313725, -0.1372549 , -0.18431373],
#          [-0.44313725, -0.1372549 , -0.18431373],
#          [-0.44313725, -0.1372549 , -0.18431373]],
#
#         [[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686]],
#
#         [[-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          [-0.25490196,  0.05882353, -0.02745098],
#          ...,
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686],
#          [-0.45098039, -0.14509804, -0.19215686]],
#
#         ...,
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.05882353,  0.01960784],
#          ...,
#          [-0.49803922, -0.15294118, -0.12941176],
#          [-0.5372549 , -0.21568627, -0.20784314],
#          [-0.56078431, -0.25490196, -0.25490196]],
#
#         [[-0.25490196,  0.05098039,  0.00392157],
#          [-0.25490196,  0.05098039,  0.00392157],
#          [-0.23921569,  0.06666667,  0.01176471],
#          ...,
#          [-0.46666667, -0.11372549, -0.11372549],
#          [-0.51372549, -0.17647059, -0.18431373],
#          [-0.54509804, -0.21568627, -0.23137255]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.41176471, -0.05882353, -0.05882353],
#          [-0.46666667, -0.12941176, -0.1372549 ],
#          [-0.52156863, -0.19215686, -0.20784314]]],
#
#
#        [[[-0.25490196,  0.06666667, -0.03529412],
#          [-0.25490196,  0.06666667, -0.03529412],
#          [-0.25490196,  0.06666667, -0.03529412],
#          ...,
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608]],
#
#         [[-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          ...,
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608],
#          [-0.34901961, -0.04313725, -0.09019608]],
#
#         [[-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          [-0.24705882,  0.0745098 , -0.02745098],
#          ...,
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922],
#          [-0.35686275, -0.05098039, -0.09803922]],
#
#         ...,
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.49019608, -0.16078431, -0.17647059],
#          [-0.55294118, -0.17647059, -0.22352941],
#          [-0.58431373, -0.17647059, -0.24705882]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.48235294, -0.14509804, -0.16078431],
#          [-0.5372549 , -0.14509804, -0.2       ],
#          [-0.56078431, -0.14509804, -0.22352941]],
#
#         [[-0.24705882,  0.05882353,  0.01176471],
#          [-0.24705882,  0.05882353,  0.01176471],
#          [-0.23921569,  0.06666667,  0.01960784],
#          ...,
#          [-0.43529412, -0.09019608, -0.10588235],
#          [-0.49803922, -0.10588235, -0.16078431],
#          [-0.52941176, -0.11372549, -0.19215686]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)
# (<tf.Tensor: shape=(15, 256, 256, 3), dtype=float64, numpy=
# array([[[[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.06666667,  0.03529412,  0.16078431],
#          [-0.06666667,  0.03529412,  0.16078431],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         [[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.0745098 ,  0.02745098,  0.15294118],
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         [[ 0.85098039,  0.79607843,  0.88235294],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          [ 0.83529412,  0.78039216,  0.86666667],
#          ...,
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.09019608,  0.01176471,  0.1372549 ],
#          [-0.05882353,  0.04313725,  0.16862745]],
#
#         ...,
#
#         [[-0.17647059, -0.0745098 ,  0.14509804],
#          [-0.16862745, -0.06666667,  0.15294118],
#          [-0.16862745, -0.0745098 ,  0.1372549 ],
#          ...,
#          [-0.59215686, -0.52156863, -0.51372549],
#          [-0.58431373, -0.52941176, -0.49019608],
#          [-0.60784314, -0.55294118, -0.50588235]],
#
#         [[-0.33333333, -0.23921569,  0.00392157],
#          [-0.33333333, -0.23921569,  0.00392157],
#          [-0.31764706, -0.23921569, -0.01960784],
#          ...,
#          [-0.63921569, -0.56862745, -0.56078431],
#          [-0.64705882, -0.6       , -0.56078431],
#          [-0.65490196, -0.61568627, -0.56862745]],
#
#         [[-0.90588235, -0.81176471, -0.56862745],
#          [-0.92156863, -0.82745098, -0.59215686],
#          [-0.91372549, -0.82745098, -0.60784314],
#          ...,
#          [-0.97647059, -0.92156863, -0.91372549],
#          [-0.98431373, -0.94509804, -0.90588235],
#          [-0.91372549, -0.8745098 , -0.82745098]]],
#
#
#        [[[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.80392157],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.00392157,  0.06666667],
#          [-0.05882353, -0.01176471,  0.05882353],
#          [-0.05882353, -0.01176471,  0.05882353]],
#
#         [[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.80392157],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.00392157,  0.0745098 ],
#          [-0.05882353, -0.01176471,  0.05882353],
#          [-0.05882353, -0.01176471,  0.05882353]],
#
#         [[ 0.82745098,  0.80392157,  0.81176471],
#          [ 0.81960784,  0.78823529,  0.81176471],
#          [ 0.81176471,  0.76470588,  0.82745098],
#          ...,
#          [-0.06666667, -0.01176471,  0.05882353],
#          [-0.06666667, -0.01960784,  0.05098039],
#          [-0.06666667, -0.01960784,  0.05098039]],
#
#         ...,
#
#         [[-0.16078431, -0.0745098 ,  0.14509804],
#          [-0.15294118, -0.06666667,  0.14509804],
#          [-0.16862745, -0.0745098 ,  0.1372549 ],
#          ...,
#          [-0.59215686, -0.52156863, -0.51372549],
#          [-0.58431373, -0.52941176, -0.49019608],
#          [-0.60784314, -0.55294118, -0.50588235]],
#
#         [[-0.30980392, -0.22352941, -0.01176471],
#          [-0.31764706, -0.23137255, -0.01176471],
#          [-0.31764706, -0.23137255, -0.01176471],
#          ...,
#          [-0.63921569, -0.56862745, -0.56078431],
#          [-0.64705882, -0.6       , -0.56078431],
#          [-0.65490196, -0.61568627, -0.56862745]],
#
#         [[-0.86666667, -0.78039216, -0.56078431],
#          [-0.89019608, -0.80392157, -0.58431373],
#          [-0.89803922, -0.81176471, -0.59215686],
#          ...,
#          [-0.97647059, -0.92156863, -0.91372549],
#          [-0.98431373, -0.94509804, -0.90588235],
#          [-0.91372549, -0.8745098 , -0.82745098]]],
#
#
#        [[[ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74901961,  0.80392157],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         [[ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74117647,  0.81176471],
#          [ 0.84313725,  0.74901961,  0.80392157],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         [[ 0.85098039,  0.73333333,  0.82745098],
#          [ 0.85098039,  0.73333333,  0.81960784],
#          [ 0.85098039,  0.74117647,  0.81176471],
#          ...,
#          [-0.08235294, -0.03529412,  0.03529412],
#          [-0.09019608, -0.04313725,  0.02745098],
#          [-0.09019608, -0.04313725,  0.02745098]],
#
#         ...,
#
#         [[-0.10588235, -0.06666667,  0.15294118],
#          [-0.11372549, -0.08235294,  0.14509804],
#          [-0.1372549 , -0.09803922,  0.12156863],
#          ...,
#          [-0.6       , -0.5372549 , -0.50588235],
#          [-0.59215686, -0.52941176, -0.49803922],
#          [-0.62352941, -0.56862745, -0.5372549 ]],
#
#         [[-0.27058824, -0.22352941, -0.03529412],
#          [-0.28627451, -0.23921569, -0.05098039],
#          [-0.30196078, -0.2627451 , -0.05098039],
#          ...,
#          [-0.63137255, -0.56862745, -0.5372549 ],
#          [-0.63921569, -0.59215686, -0.56078431],
#          [-0.68627451, -0.63921569, -0.60784314]],
#
#         [[-0.81960784, -0.77254902, -0.58431373],
#          [-0.84313725, -0.80392157, -0.60784314],
#          [-0.85882353, -0.82745098, -0.60784314],
#          ...,
#          [-0.98431373, -0.92156863, -0.89019608],
#          [-0.97647059, -0.92941176, -0.89803922],
#          [-0.96078431, -0.91372549, -0.88235294]]],
#
#
#        ...,
#
#
#        [[[ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         [[ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          [ 0.95294118,  0.83529412,  0.85882353],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         [[ 0.94509804,  0.85098039,  0.86666667],
#          [ 0.94509804,  0.85098039,  0.86666667],
#          [ 0.94509804,  0.85098039,  0.86666667],
#          ...,
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549],
#          [-0.05098039,  0.05098039,  0.11372549]],
#
#         ...,
#
#         [[-0.09803922,  0.01960784,  0.10588235],
#          [-0.09803922,  0.01176471,  0.09019608],
#          [-0.10588235, -0.00392157,  0.05098039],
#          ...,
#          [-0.57647059, -0.49803922, -0.52156863],
#          [-0.59215686, -0.50588235, -0.55294118],
#          [-0.60784314, -0.52156863, -0.56078431]],
#
#         [[-0.27843137, -0.16078431, -0.09019608],
#          [-0.27058824, -0.16078431, -0.09019608],
#          [-0.2627451 , -0.16862745, -0.12941176],
#          ...,
#          [-0.60784314, -0.52156863, -0.56862745],
#          [-0.68627451, -0.60784314, -0.63921569],
#          [-0.69411765, -0.61568627, -0.63921569]],
#
#         [[-0.82745098, -0.70980392, -0.63921569],
#          [-0.82745098, -0.71764706, -0.65490196],
#          [-0.81176471, -0.71764706, -0.67843137],
#          ...,
#          [-0.96078431, -0.8745098 , -0.92156863],
#          [-0.97647059, -0.89803922, -0.92156863],
#          [-0.94509804, -0.85882353, -0.89019608]]],
#
#
#        [[[ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          ...,
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059]],
#
#         [[ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.91372549,  0.89019608,  0.89803922],
#          [ 0.92156863,  0.89803922,  0.90588235],
#          ...,
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059],
#          [-0.02745098,  0.05882353,  0.17647059]],
#
#         [[ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.91372549,  0.90588235,  0.90588235],
#          ...,
#          [-0.01960784,  0.0745098 ,  0.16862745],
#          [-0.01176471,  0.0745098 ,  0.16862745],
#          [-0.01176471,  0.0745098 ,  0.16862745]],
#
#         ...,
#
#         [[-0.11372549, -0.01176471,  0.20784314],
#          [-0.09803922, -0.00392157,  0.2       ],
#          [-0.06666667, -0.01176471,  0.12156863],
#          ...,
#          [-0.56078431, -0.48235294, -0.50588235],
#          [-0.56862745, -0.49019608, -0.52941176],
#          [-0.58431373, -0.49803922, -0.54509804]],
#
#         [[-0.28627451, -0.17647059,  0.02745098],
#          [-0.2627451 , -0.16862745,  0.02745098],
#          [-0.22352941, -0.17647059, -0.05098039],
#          ...,
#          [-0.59215686, -0.50588235, -0.55294118],
#          [-0.67058824, -0.59215686, -0.61568627],
#          [-0.67843137, -0.6       , -0.62352941]],
#
#         [[-0.82745098, -0.71764706, -0.51372549],
#          [-0.81176471, -0.71764706, -0.52941176],
#          [-0.76470588, -0.71764706, -0.59215686],
#          ...,
#          [-0.92941176, -0.84313725, -0.89019608],
#          [-0.94509804, -0.86666667, -0.89803922],
#          [-0.91372549, -0.83529412, -0.85882353]]],
#
#
#        [[[ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          [ 0.90588235,  0.90588235,  0.90588235],
#          ...,
#          [-0.01960784,  0.05882353,  0.19215686],
#          [-0.01176471,  0.05098039,  0.20784314],
#          [-0.00392157,  0.05098039,  0.20784314]],
#
#         [[ 0.91372549,  0.91372549,  0.91372549],
#          [ 0.91372549,  0.91372549,  0.91372549],
#          [ 0.91372549,  0.91372549,  0.91372549],
#          ...,
#          [-0.01960784,  0.05882353,  0.19215686],
#          [-0.00392157,  0.05098039,  0.2       ],
#          [-0.00392157,  0.05098039,  0.20784314]],
#
#         [[ 0.90588235,  0.92941176,  0.92941176],
#          [ 0.90588235,  0.92941176,  0.92941176],
#          [ 0.90588235,  0.92941176,  0.92941176],
#          ...,
#          [-0.01960784,  0.06666667,  0.18431373],
#          [-0.01960784,  0.06666667,  0.18431373],
#          [-0.01960784,  0.06666667,  0.18431373]],
#
#         ...,
#
#         [[-0.01176471,  0.04313725,  0.30196078],
#          [-0.01960784,  0.03529412,  0.27843137],
#          [-0.05098039,  0.01960784,  0.2       ],
#          ...,
#          [-0.4745098 , -0.43529412, -0.45098039],
#          [-0.52156863, -0.45098039, -0.46666667],
#          [-0.55294118, -0.4745098 , -0.49019608]],
#
#         [[-0.20784314, -0.12941176,  0.12941176],
#          [-0.20784314, -0.12941176,  0.11372549],
#          [-0.22352941, -0.1372549 ,  0.02745098],
#          ...,
#          [-0.5372549 , -0.49803922, -0.51372549],
#          [-0.63137255, -0.56862745, -0.56078431],
#          [-0.63921569, -0.56862745, -0.56078431]],
#
#         [[-0.83529412, -0.76470588, -0.50588235],
#          [-0.80392157, -0.73333333, -0.49019608],
#          [-0.80392157, -0.71764706, -0.55294118],
#          ...,
#          [-0.89019608, -0.85098039, -0.86666667],
#          [-0.92156863, -0.85882353, -0.85098039],
#          [-0.86666667, -0.79607843, -0.78823529]]]])>, <tf.Tensor: shape=(1,), dtype=float64, numpy=array([1.])>)

# %%
videos = videos[:3]
labels = labels[:3]

# %%
y = onehot_encode_label(labels)

# %%
videos
# Out:
# ['/content/drive/MyDrive/HAR/AR_CNN_1/hmdb51/draw_sword/19th_Century_Cavalry_Sabre_Draw_draw_sword_u_nm_np1_fr_bad_0.avi',
#  '/content/drive/MyDrive/HAR/AR_CNN_1/hmdb51/draw_sword/19th_Century_Cavalry_Sabre_Draw_draw_sword_u_nm_np1_fr_bad_1.avi',
#  '/content/drive/MyDrive/HAR/AR_CNN_1/hmdb51/draw_sword/A_point_about_drawing_swords_draw_sword_u_nm_np1_fr_med_0.avi']

# %%
dataset = tf.data.Dataset.list_files(videos)
